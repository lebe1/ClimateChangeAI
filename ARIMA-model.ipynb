# %%
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA

# %%
# Import data
df_train = pd.read_csv('scaled_train.csv', sep=';')
df_test = pd.read_csv('scaled_test.csv', sep=';')

# %%
# Check for correct import
pd.set_option('display.max_colwidth', 2000)

df_train.head()

# Check for rows and columns size
# print(df_train.shape)
# Out:
#    YYYY  MM  DD  DOY  2m_temp_max  2m_temp_mean  2m_temp_min  2m_dp_temp_max  \
# 0  1981   1   1    1    -1.694344     -1.590316    -1.527666       -1.637383
# 1  1981   1   2    2    -2.039424     -1.895327    -1.624605       -1.904712
# 2  1981   1   3    3    -1.538502     -1.437811    -1.285320       -1.306405
# 3  1981   1   4    4    -1.493976     -1.379155    -1.454962       -1.166376
# 4  1981   1   5    5    -2.206398     -2.129951    -1.830599       -2.095660
#
#    2m_dp_temp_mean  2m_dp_temp_min  ...  surf_net_therm_rad_max  \
# 0        -1.767661       -1.858007  ...               -1.267167
# 1        -1.755301       -1.485195  ...               -1.529381
# 2        -1.310363       -1.147333  ...               -1.192249
# 3        -1.162050       -1.368691  ...               -0.592905
# 4        -2.051927       -1.834707  ...               -0.855118
#
#    surf_net_therm_rad_mean  surf_press  total_et      prec  volsw_123  \
# 0                -1.200392   -1.494360 -1.161267  0.281353  -2.133464
# 1                -1.336408   -1.500933 -1.078582  1.401365  -2.133464
# 2                -1.563102   -1.629353 -1.078582  1.085645  -2.133464
# 3                -1.155054   -1.741932 -1.078582  2.424368  -2.133464
# 4                -1.109715   -1.662385 -0.905697  2.101592  -2.133464
#
#     volsw_4      elev      lon      lat
# 0 -1.708602  0.094791 -0.69264 -0.91951
# 1 -1.708602  0.094791 -0.69264 -0.91951
# 2 -1.708602  0.094791 -0.69264 -0.91951
# 3 -1.708602  0.094791 -0.69264 -0.91951
# 4 -1.708602  0.094791 -0.69264 -0.91951
#
# [5 rows x 28 columns]

# %%
# Extract the relevant columns for time series analysis
# Selecting 'prec' column for prediction

y_train = df_train[['YYYY', 'MM', 'DD', 'prec']]
x_train = df_train.drop(['YYYY', 'MM', 'DD', 'DOY', 'prec'], axis=1)


# Convert date columns to a datetime format

y_train['Date'] = pd.to_datetime(dict(year= y_train['YYYY'], month= y_train['MM'], day= y_train['DD']))
x_train['Date'] = pd.to_datetime(dict(year= y_train['YYYY'], month= y_train['MM'], day= y_train['DD']))

y_train = y_train.set_index('Date')
x_train = x_train.set_index('Date')

y_train.index = pd.DatetimeIndex(y_train.index).to_period('D')
x_train.index = pd.DatetimeIndex(x_train.index).to_period('D')

# Drop the now redundant columns
y_train.drop(['YYYY', 'MM', 'DD'], axis=1, inplace=True)

# Check for correct dataframe
y_train.head()
# Out:
# /tmp/ipykernel_11659/1775012260.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train['Date'] = pd.to_datetime(dict(year= y_train['YYYY'], month= y_train['MM'], day= y_train['DD']))
#                 prec
# Date
# 1981-01-01  0.281353
# 1981-01-02  1.401365
# 1981-01-03  1.085645
# 1981-01-04  2.424368
# 1981-01-05  2.101592

# %%
# Check for correct x dataframe
x_train.head()
# Out:
#             2m_temp_max  2m_temp_mean  2m_temp_min  2m_dp_temp_max  \
# Date
# 1981-01-01    -1.694344     -1.590316    -1.527666       -1.637383
# 1981-01-02    -2.039424     -1.895327    -1.624605       -1.904712
# 1981-01-03    -1.538502     -1.437811    -1.285320       -1.306405
# 1981-01-04    -1.493976     -1.379155    -1.454962       -1.166376
# 1981-01-05    -2.206398     -2.129951    -1.830599       -2.095660
#
#             2m_dp_temp_mean  2m_dp_temp_min  10m_wind_u  10m_wind_v  fcst_alb  \
# Date
# 1981-01-01        -1.767661       -1.858007    0.321671   -0.522413  1.314577
# 1981-01-02        -1.755301       -1.485195    0.392013   -0.346318  1.379199
# 1981-01-03        -1.310363       -1.147333    0.251329    0.358061  1.379199
# 1981-01-04        -1.162050       -1.368691    0.110645   -0.610460  1.379199
# 1981-01-05        -2.051927       -1.834707    0.392013   -1.138745  1.379199
#
#             lai_high_veg  ...  surf_net_solar_rad_mean  \
# Date                      ...
# 1981-01-01     -0.065803  ...                -1.208113
# 1981-01-02     -0.065803  ...                -1.180225
# 1981-01-03     -0.065803  ...                -1.138393
# 1981-01-04     -0.065803  ...                -1.333611
# 1981-01-05     -0.065803  ...                -1.236002
#
#             surf_net_therm_rad_max  surf_net_therm_rad_mean  surf_press  \
# Date
# 1981-01-01               -1.267167                -1.200392   -1.494360
# 1981-01-02               -1.529381                -1.336408   -1.500933
# 1981-01-03               -1.192249                -1.563102   -1.629353
# 1981-01-04               -0.592905                -1.155054   -1.741932
# 1981-01-05               -0.855118                -1.109715   -1.662385
#
#             total_et  volsw_123   volsw_4      elev      lon      lat
# Date
# 1981-01-01 -1.161267  -2.133464 -1.708602  0.094791 -0.69264 -0.91951
# 1981-01-02 -1.078582  -2.133464 -1.708602  0.094791 -0.69264 -0.91951
# 1981-01-03 -1.078582  -2.133464 -1.708602  0.094791 -0.69264 -0.91951
# 1981-01-04 -1.078582  -2.133464 -1.708602  0.094791 -0.69264 -0.91951
# 1981-01-05 -0.905697  -2.133464 -1.708602  0.094791 -0.69264 -0.91951
#
# [5 rows x 23 columns]

# %%
# Fit the ARIMA model
# Example order (p,d,q) - adjust as needed
model = ARIMA(y_train, exog=x_train, order=(5, 1, 0))
model_fit = model.fit()
# Out:
# /home/funny/.virtualenvs/climateChangeAI/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/funny/.virtualenvs/climateChangeAI/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/funny/.virtualenvs/climateChangeAI/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Forecasting example (adjust the number of periods)
# Example: forecast for the next 10 periods
#forecast = model_fit.forecast(steps=10, exog=df_test.iloc[-10:])
df_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Forecasting example (adjust the number of periods)
#       2 # Example: forecast for the next 10 periods
#       3 #forecast = model_fit.forecast(steps=10, exog=df_test.iloc[-10:])
# ----> 4 df_test.head()
#
# NameError: name 'df_test' is not defined
