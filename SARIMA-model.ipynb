# %% [markdown]
# <a href="https://colab.research.google.com/github/lebe1/ClimateChangeAI/blob/main/SARIMA-model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA

# %%
# Import data
df_train = pd.read_csv('scaled_train.csv', sep=';')
df_test = pd.read_csv('scaled_test.csv', sep=';')

# %%
# Check for correct import
pd.set_option('display.max_colwidth', 2000)

df_train.head()

# Check for rows and columns size
# print(df_train.shape)
# Out:
#    YYYY  MM  DD  DOY  2m_temp_max  2m_temp_mean  2m_temp_min  2m_dp_temp_max  \
# 0  1981   1   1    1    -0.848457     -0.648853    -0.465513       -0.609571
# 1  1981   1   2    2    -1.036223     -0.788476    -0.525469       -0.597103
# 2  1981   1   3    3    -0.638602     -0.381243    -0.093786       -0.272918
# 3  1981   1   4    4    -0.892638     -0.602312    -0.321619       -0.435011
# 4  1981   1   5    5    -1.257123     -1.044451    -0.729319       -0.971161
#
#    2m_dp_temp_mean  2m_dp_temp_min  ...  surf_net_therm_rad_max  \
# 0        -0.556990       -0.549324  ...               -0.646738
# 1        -0.629726       -0.629324  ...               -0.572827
# 2        -0.120574        0.033530  ...               -2.494519
# 3        -0.363027       -0.229326  ...               -0.905427
# 4        -1.017651       -0.880751  ...                0.203242
#
#    surf_net_therm_rad_mean  surf_press  total_et      prec  volsw_123  \
# ...

# %%
# Fit the ARIMA model
y_train = df_train['prec']
x_train = df_train.drop(['prec'], axis=1)
model = ARIMA(y_train, exog=x_train, order=(1, 0, 1), seasonal_order=(1, 0, 0, 365))
model_fit = model.fit()
